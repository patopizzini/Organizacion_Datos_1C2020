# %%
## IMPORTACIÓN GENERAL DE LIBRERIAS Y VISUALIZACIÓN DE DATOS (matplotlib y seaborn)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as DT
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')
plt.style.use('default') 
sns.set(style="whitegrid") 
plt.rcParams['figure.figsize'] = (15, 10)

# %%
#Leemos el CSV
nlp = pd.read_csv('../data/train.csv')

# %%
nlp.head(50)
# Out:
#     id keyword                       location  \
# 0    1     NaN                            NaN
# 1    4     NaN                            NaN
# 2    5     NaN                            NaN
# 3    6     NaN                            NaN
# 4    7     NaN                            NaN
# 5    8     NaN                            NaN
# 6   10     NaN                            NaN
# 7   13     NaN                            NaN
# 8   14     NaN                            NaN
# 9   15     NaN                            NaN
# 10  16     NaN                            NaN
# 11  17     NaN                            NaN
# 12  18     NaN                            NaN
# 13  19     NaN                            NaN
# 14  20     NaN                            NaN
# 15  23     NaN                            NaN
# 16  24     NaN                            NaN
# 17  25     NaN                            NaN
# 18  26     NaN                            NaN
# 19  28     NaN                            NaN
# 20  31     NaN                            NaN
# 21  32     NaN                            NaN
# 22  33     NaN                            NaN
# 23  34     NaN                            NaN
# 24  36     NaN                            NaN
# 25  37     NaN                            NaN
# 26  38     NaN                            NaN
# 27  39     NaN                            NaN
# 28  40     NaN                            NaN
# 29  41     NaN                            NaN
# 30  44     NaN                            NaN
# 31  48  ablaze                     Birmingham
# 32  49  ablaze  Est. September 2012 - Bristol
# 33  50  ablaze                         AFRICA
# 34  52  ablaze               Philadelphia, PA
# 35  53  ablaze                     London, UK
# 36  54  ablaze                       Pretoria
# 37  55  ablaze                   World Wide!!
# 38  56  ablaze                            NaN
# 39  57  ablaze                 Paranaque City
# 40  59  ablaze                 Live On Webcam
# 41  61  ablaze                            NaN
# 42  62  ablaze                      milky way
# 43  63  ablaze                            NaN
# 44  64  ablaze                            NaN
# 45  65  ablaze                            NaN
# 46  66  ablaze      GREENSBORO,NORTH CAROLINA
# 47  67  ablaze                            NaN
# 48  68  ablaze                 Live On Webcam
# 49  71  ablaze                       England.
#
#                                                  text  target
# 0   Our Deeds are the Reason of this #earthquake M...       1
# 1              Forest fire near La Ronge Sask. Canada       1
# 2   All residents asked to 'shelter in place' are ...       1
# 3   13,000 people receive #wildfires evacuation or...       1
# 4   Just got sent this photo from Ruby #Alaska as ...       1
# 5   #RockyFire Update => California Hwy. 20 closed...       1
# 6   #flood #disaster Heavy rain causes flash flood...       1
# 7   I'm on top of the hill and I can see a fire in...       1
# 8   There's an emergency evacuation happening now ...       1
# 9   I'm afraid that the tornado is coming to our a...       1
# 10        Three people died from the heat wave so far       1
# 11  Haha South Tampa is getting flooded hah- WAIT ...       1
# 12  #raining #flooding #Florida #TampaBay #Tampa 1...       1
# 13            #Flood in Bago Myanmar #We arrived Bago       1
# 14  Damage to school bus on 80 in multi car crash ...       1
# 15                                     What's up man?       0
# 16                                      I love fruits       0
# 17                                   Summer is lovely       0
# 18                                  My car is so fast       0
# 19                       What a goooooooaaaaaal!!!!!!       0
# 20                             this is ridiculous....       0
# 21                                  London is cool ;)       0
# 22                                        Love skiing       0
# 23                              What a wonderful day!       0
# 24                                           LOOOOOOL       0
# 25                     No way...I can't eat that shit       0
# 26                              Was in NYC last week!       0
# 27                                 Love my girlfriend       0
# 28                                          Cooool :)       0
# 29                                 Do you like pasta?       0
# 30                                           The end!       0
# 31  @bbcmtd Wholesale Markets ablaze http://t.co/l...       1
# 32  We always try to bring the heavy. #metal #RT h...       0
# 33  #AFRICANBAZE: Breaking news:Nigeria flag set a...       1
# 34                 Crying out for more! Set me ablaze       0
# 35  On plus side LOOK AT THE SKY LAST NIGHT IT WAS...       0
# 36  @PhDSquares #mufc they've built so much hype a...       0
# 37  INEC Office in Abia Set Ablaze - http://t.co/3...       1
# 38  Barbados #Bridgetown JAMAICA ÛÒ Two cars set ...       1
# 39                             Ablaze for you Lord :D       0
# 40  Check these out: http://t.co/rOI2NSmEJJ http:/...       0
# 41  on the outside you're ablaze and alive\r\nbut ...       0
# 42  Had an awesome time visiting the CFC head offi...       0
# 43       SOOOO PUMPED FOR ABLAZE ???? @southridgelife       0
# 44  I wanted to set Chicago ablaze with my preachi...       0
# 45  I gained 3 followers in the last week. You? Kn...       0
# 46  How the West was burned: Thousands of wildfire...       1
# 47  Building the perfect tracklist to life leave t...       0
# 48  Check these out: http://t.co/rOI2NSmEJJ http:/...       0
# 49  First night with retainers in. It's quite weir...       0

# %%
nlp.shape
# Out:
# (7613, 5)

# %%
nlp['target'].value_counts()
# Out:
# 0    4342
# 1    3271
# Name: target, dtype: int64

# %%
sin_keyword = nlp['keyword'].isnull().sum()
con_keyword = nlp['keyword'].count()-sin_keyword

sizes = [con_keyword, sin_keyword]
nombres = ["Con keyword", "Sin keyword"]

plt.figure(figsize=(11.7, 8.27))
plt.title('Porcentaje de tweets con keyword asociado', fontsize=35)
plt.pie(sizes, labels=nombres, autopct='%1.1f%%', shadow=True, startangle=90, explode=(0.1, 0))
plt.show()

# %%
cant_keyword = nlp['keyword'].value_counts().iloc[:20]

# %%
# Tamaño para hojas A4.
plt.figure(figsize=(11.7, 8.27))

ax = sns.barplot(x=cant_keyword.values, y=cant_keyword.index)

ax.set_title("Keywords",fontsize=15)
ax.set_xlabel("cant",fontsize=15)
ax.set_ylabel("palabra clave",fontsize=15)
# Out:
# Text(0, 0.5, 'palabra clave')

# %%
fatalities = nlp[nlp['keyword']=='fatalities']
fatalities.head(10)
# Out:
#         id     keyword                   location  \
# 3616  5162  fatalities                        NaN
# 3617  5164  fatalities                   New York
# 3618  5165  fatalities          New York City ,NY
# 3619  5166  fatalities                        NaN
# 3620  5168  fatalities      Corpus Christi, Texas
# 3621  5169  fatalities                  Cape Town
# 3622  5170  fatalities                        NaN
# 3623  5171  fatalities  Wolverhampton/Brum/Jersey
# 3624  5172  fatalities          Chamblee, Georgia
# 3625  5174  fatalities           Official Website
#
#                                                    text  target
# 3616  EXCLUSIVE: In 179 fatalities involving on-duty...       1
# 3617  #NYC #News Legionnaires death toll rises to 8 ...       1
# 3618  Let's fraction the vital need for Our fataliti...       0
# 3619  Las Vegas in top 5 cities for red-light runnin...       0
# 3620  We are totally unprepared for an EMP attack. B...       1
# 3621  City implores motorists not to speed after mor...       1
# 3622  @kyrikoni @ExpressandStar Who said veg and fru...       0
# 3623  Understand that there are no fatalities as no ...       1
# 3624  As of the 6-month mark there were a total of 6...       1
# 3625  #HSE releases annual workplace facilities data...       0

# %%
target1 = nlp[nlp['target']==1]
cant_keyword_target1 = target1['keyword'].value_counts().iloc[:20]

# %%
# Tamaño para hojas A4.
plt.figure(figsize=(11.7, 8.27))

ax = sns.barplot(x=cant_keyword_target1.values, y=cant_keyword_target1.index)

ax.set_title("Keywords con target 1",fontsize=15)
ax.set_xlabel("cant",fontsize=15)
ax.set_ylabel("palabra clave",fontsize=15)
# Out:
# Text(0, 0.5, 'palabra clave')

# %%
target0 = nlp[nlp['target']==0]
cant_keyword_target0 = target0['keyword'].value_counts().iloc[:20]

# %%
# Tamaño para hojas A4.
plt.figure(figsize=(11.7, 8.27))

ax = sns.barplot(x=cant_keyword_target0.values, y=cant_keyword_target0.index)

ax.set_title("Keywords con target 0",fontsize=15)
ax.set_xlabel("cant",fontsize=15)
ax.set_ylabel("palabra clave",fontsize=15)
# Out:
# Text(0, 0.5, 'palabra clave')

# %%
keywords_df = nlp.groupby(['keyword', 'target'])[['text']].count().reset_index()
keywords_df['populares'] = keywords_df['keyword'].isin(cant_keyword.index)
keywords_df = keywords_df[keywords_df['populares']==True]
keywords_df.head(15)
# Out:
#          keyword  target  text  populares
# 15    armageddon       0    37       True
# 16    armageddon       1     5       True
# 57   body%20bags       0    40       True
# 58   body%20bags       1     1       True
# 97      collided       0    17       True
# 98      collided       1    23       True
# 113       damage       0    22       True
# 114       damage       1    19       True
# 124       deluge       0    36       True
# 125       deluge       1     6       True
# 187     evacuate       0    15       True
# 188     evacuate       1    25       True
# 201       famine       0    13       True
# 202       famine       1    26       True
# 205   fatalities       0    19       True

# %%
# Tamaño para hojas A4.
plt.figure(figsize=(11.7, 8.27))

ax = sns.barplot(x='text', y='keyword', hue='target', data=keywords_df)

ax.set_title("Keywords con target 0",fontsize=15)
ax.set_xlabel("cant",fontsize=15)
ax.set_ylabel("palabra clave",fontsize=15)
# Out:
# Text(0, 0.5, 'palabra clave')

# %%
emojis = nlp[['keyword', 'target', 'text']]
emojis.dropna(inplace=True)
emojis
# Out:
#       keyword  target                                               text
# 31     ablaze       1  @bbcmtd Wholesale Markets ablaze http://t.co/l...
# 32     ablaze       0  We always try to bring the heavy. #metal #RT h...
# 33     ablaze       1  #AFRICANBAZE: Breaking news:Nigeria flag set a...
# 34     ablaze       0                 Crying out for more! Set me ablaze
# 35     ablaze       0  On plus side LOOK AT THE SKY LAST NIGHT IT WAS...
# ...       ...     ...                                                ...
# 7578  wrecked       0   @jt_ruff23 @cameronhacker and I wrecked you both
# 7579  wrecked       0  Three days off from work and they've pretty mu...
# 7580  wrecked       0  #FX #forex #trading Cramer: Iger's 3 words tha...
# 7581  wrecked       0  @engineshed Great atmosphere at the British Li...
# 7582  wrecked       0  Cramer: Iger's 3 words that wrecked Disney's s...
#
# [7552 rows x 3 columns]

# %%
#emojis['ask'] = emojis['text'].str.count(':D' and '[:)]')
#emojis['ask'] = emojis['text'].str.count('[?]' and '[!]')
emojis['ask'] = emojis['text'].str.count(emojis['keyword'])
emojis['ask'] = emojis['text'].str.count()
emojis_agrupado = emojis.groupby('target')[['ask']].agg(['count', 'sum'])
emojis_agrupado.head(50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-1594d91dd557> in <module>
#       2 #emojis['ask'] = emojis['text'].str.count('[?]' and '[!]')
#       3 emojis['key_str'] = emojis['keyword'].astype(str)
# ----> 4 emojis['ask'] = emojis['text'].str.count(emojis['key_str'])
#       5 emojis['ask'] = emojis['text'].str.count()
#       6 emojis_agrupado = emojis.groupby('target')[['ask']].agg(['count', 'sum'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\strings.py in wrapper(self, *args, **kwargs)
#    1841                 )
#    1842                 raise TypeError(msg)
# -> 1843             return func(self, *args, **kwargs)
#    1844
#    1845         wrapper.__name__ = func_name
#
# ~\Anaconda3\lib\site-packages\pandas\core\strings.py in wrapper2(self, pat, flags, **kwargs)
#    1874     @forbid_nonstring_types(forbidden_types, name=name)
#    1875     def wrapper2(self, pat, flags=0, **kwargs):
# -> 1876         result = f(self._parent, pat, flags=flags, **kwargs)
#    1877         return self._wrap_result(result)
#    1878
#
# ~\Anaconda3\lib\site-packages\pandas\core\strings.py in str_count(arr, pat, flags)
#     210     Int64Index([0, 0, 2, 1], dtype='int64')
#     211     """
# --> 212     regex = re.compile(pat, flags=flags)
#     213     f = lambda x: len(regex.findall(x))
#     214     return _na_map(f, arr, dtype=int)
#
# ~\Anaconda3\lib\re.py in compile(pattern, flags)
#     232 def compile(pattern, flags=0):
#     233     "Compile a regular expression pattern, returning a Pattern object."
# --> 234     return _compile(pattern, flags)
#     235
#     236 def purge():
#
# ~\Anaconda3\lib\re.py in _compile(pattern, flags)
#     274         flags = flags.value
#     275     try:
# --> 276         return _cache[type(pattern), pattern, flags]
#     277     except KeyError:
#     278         pass
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __hash__(self)
#    1884         raise TypeError(
#    1885             "{0!r} objects are mutable, thus they cannot be"
# -> 1886             " hashed".format(self.__class__.__name__)
#    1887         )
#    1888
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed

# %%
emojis_agrupdo.pyplot.pie()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-eefe4482404e> in <module>
# ----> 1 emojis_agrupdo.pyplot.pie()
#
# NameError: name 'emojis_agrupdo' is not defined

# %%
nlp_sin_nulos = nlp.dropna(subset=['keyword'])
nlp_sin_nulos['h'] = nlp_sin_nulos['text'].str.count("#")
nlp_sin_nulos = nlp_sin_nulos[nlp_sin_nulos['target']==1]
nlp_sin_nulos = nlp_sin_nulos[nlp_sin_nulos['h']==1]
nlp_sin_nulos['hashtags'] = nlp_sin_nulos['text'].str.findall(r'#.*?(?=\s|$)')
nlp_sin_nulos['hashtags'] = nlp_sin_nulos['hashtags'].astype(str)
nlp_sin_nulos = nlp_sin_nulos.iloc[:50]
nlp_sin_nulos.head(15)
# Out:
#       id              keyword                   location  \
# 33    50               ablaze                     AFRICA
# 38    56               ablaze                        NaN
# 68    97             accident              Nashville, TN
# 100  144             accident                         UK
# 136  196  airplane%20accident      19.600858, -99.047821
# 151  216  airplane%20accident        Somewhere Out There
# 170  245  airplane%20accident                    Toronto
# 171  246            ambulance                        NaN
# 173  248            ambulance       New York / Worldwide
# 174  249            ambulance                        NaN
# 196  276            ambulance                        NaN
# 203  287            ambulance                        USA
# 204  289            ambulance          Hannover, Germany
# 257  365         annihilation                        NaN
# 317  462           armageddon  California, United States
#
#                                                   text  target  h  \
# 33   #AFRICANBAZE: Breaking news:Nigeria flag set a...       1  1
# 38   Barbados #Bridgetown JAMAICA ÛÒ Two cars set ...       1  1
# 68   Accident on I-24 W #NashvilleTraffic. Traffic ...       1  1
# 100  .@NorwayMFA #Bahrain police had previously die...       1  1
# 136  Experts in France begin examining airplane deb...       1  1
# 151  Experts in France begin examining airplane deb...       1  1
# 170  Could a drone cause an airplane accident? Pilo...       1  1
# 171  Early wake up call from my sister begging me t...       1  1
# 173  Two air ambulances on scene of serious crash b...       1  1
# 174  Twelve feared killed in Pakistani air ambulanc...       1  1
# 196  #reuters Twelve feared killed in Pakistani air...       1  1
# 203  Twelve feared killed in Pakistani air ambulanc...       1  1
# 204  Twelve feared killed in Pakistani air ambulanc...       1  1
# 257  @willienelson We need help! Horses will die!Pl...       1  1
# 317  #PBBan (Temporary:300) hyider_ghost2 @'aRmaged...       1  1
#
#                    hashtags
# 33        ['#AFRICANBAZE:']
# 38          ['#Bridgetown']
# 68   ['#NashvilleTraffic.']
# 100            ['#Bahrain']
# 136               ['#news']
# 151                ['#MLB']
# 170                   ['#']
# 171            ['#RODKiai']
# 173        ['#EMSNe\x89Û_']
# 174            ['#yugvani']
# 196            ['#reuters']
# 203          ['#worldNews']
# 204          ['#worldnews']
# 257          ['#gilbert23']
# 317              ['#PBBan']

# %%
import networkx as nx

# Tamaño para hojas A4.
plt.figure(figsize=(11.7, 8.27))

# Build your graph
G=nx.from_pandas_edgelist(nlp_sin_nulos, 'keyword', 'hashtags') #(df, from, to)

# Plot it
nx.draw(G, with_labels=True)
plt.show()
