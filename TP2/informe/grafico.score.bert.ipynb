# %%
import pandas as pd
from numpy import isnan
import datetime
from datetime import timedelta
import seaborn as sns
import matplotlib.pyplot as plt
import os

sns.set(rc={'figure.figsize':(11.7,8.27)})
# initialize list of lists 
data = [['#1', 0.77000], ['#2', 0.79000], ['#3', 0.81000], ['#4', 0.81000], ['#5', 0.82286], ['#6', 0.82991], ['#7', 0.83266]] 

#1 limpieza+lowercase+keywords+lemming
#2 limpieza+lowercase+keywords+stemming
#3 limpieza
#4 limpieza+lowercase+keywords-stopwords
#5 limpieza+lowercase
#6 lowercase+limpieza+keywords+location
#7 lowercase+limpieza+keywords

# Create the pandas DataFrame 
df = pd.DataFrame(data, columns = ['Name', 'Age']) 
  

leaderboard = pd.DataFrame(data, columns = ['Tipo de procesamiento', 'Score']) 


v = sns.barplot(x = 'Tipo de procesamiento', y = 'Score', data = leaderboard,palette=("Blues_d"))
v.set_title("Puntajes BERT por configuración de input",fontsize=30)
v.set_xlabel("Tipo de procesamiento",fontsize=15)
v.set_ylabel("Score",fontsize=15)
# Out:
# Text(0, 0.5, 'Score')
